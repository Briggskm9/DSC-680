# %% [markdown]
# Katie Briggs
# Project 3:  Finding Bigfoot

# %%
#import required libaries

import pandas as pd
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read in data set

data1=pd.read_csv('bfro_report_locations.csv',header=0)

# confirm that data is readable
data1.head(10)
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
# 5   23666  Report 23666: Passenger on the Alcan Highway s...        Class A
# 6   26604  Report 26604: Daytime sighting of reddish-colo...        Class A
# 7     179  Report 179: Man and witnesses have two seperat...        Class A
# 8     245  Report 245: Two outdoorsman fishing, loud voca...        Class A
# 9     416  Report 416: A resident's early evening sightin...        Class A
#
#               timestamp  latitude  longitude
# 0  2000-06-16T12:00:00Z  61.50000 -142.90000
# ...

# %%
# read in data set

data2=pd.read_csv('bfro_reports_geocoded.csv', header=0)

# confirm that data is readable
data2.head(10)
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
# 5  In early spring 1988, some friends of mine and...
# 6  This happened summertime early 70's (I think 7...
# 7  The foot prints of two bigfoot creatures who h...
# 8  i want to start this off by saying, I don't kn...
# 9  I was bowhunting and just sitting in my stand ...
#
#                                     location_details  \
# 0                  East side of Prince William Sound
# 1  the road is off us rt 80, i dont know the exit...
# 2  Close to Claremont down 120 not far from Kings...
# 3      Latitude & Longitude :  42.158230  -96.344197
# 4  Ward County, Just outside of a the Minuteman T...
# 5  Yancey County, North Carolina, near the summit...
# ...

# %%
# explore seasonal data

data2['season'].value_counts()
# Out:
# Summer     1765
# Fall       1413
# Spring      767
# Winter      711
# Unknown      91
# Name: season, dtype: int64

# %%
data2['season'].value_counts(sort=True).nlargest(10).plot.bar()

# %% [markdown]
# Most sightings happen during the warmer weather as people are doing more outdoor activities.  Fewer are in winter which makes us wonder is a large Primate may be capable of hibernation.

# %%
# explore sightings by state

data2['state'].value_counts()
# Out:
# Washington        563
# California        402
# Florida           292
# Ohio              276
# Oregon            241
# Illinois          232
# Texas             215
# Michigan          208
# Missouri          141
# Colorado          121
# Georgia           121
# Kentucky          112
# Pennsylvania      111
# New York          102
# West Virginia     100
# Arkansas           95
# Alabama            91
# Tennessee          91
# Oklahoma           85
# Arizona            84
# Idaho              81
# Wisconsin          80
# North Carolina     79
# Indiana            75
# Virginia           72
# Minnesota          69
# New Jersey         63
# Utah               57
# Iowa               56
# Montana            45
# Kansas             42
# New Mexico         40
# Louisiana          40
# South Carolina     38
# Maryland           34
# Wyoming            27
# Massachusetts      27
# Mississippi        21
# Alaska             20
# Connecticut        15
# Nebraska           15
# ...

# %%
data2['state'].value_counts(sort=True).nlargest(10).plot.bar()

# %% [markdown]
# The most reported sightings are in happening on the pacific states. Florida which is also swamp is in the top 5 sighting areas.

# %%
data2['precip_type'].value_counts()
# Out:
# rain    1411
# snow     149
# Name: precip_type, dtype: int64

# %%
data2.plot.scatter(x='moon_phase', y='season')

# %%
sns.distplot(data2['moon_phase'])
